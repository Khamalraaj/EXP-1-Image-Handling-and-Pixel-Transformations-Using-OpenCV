# %% [markdown]
# # Ex. No: 01
# ## Image Handling and Pixel Transformations Using OpenCV
#
# **Name :** Khamalraaj S    **Reg. No :** 212224230122    **Slot No :** ___________________

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Read the image ('Eagle_in_Flight.jpg') using OpenCV imread() as a grayscale image.

# %%
img_bgr=cv2.imread('Eagle_in_Flight.jpg',1)

# %% [markdown]
# 2. Print the image width, height & Channel

# %%
img_bgr.shape
# Out:
# (600, 768, 3)

# %% [markdown]
# 3. Display the image using matplotlib imshow().

# %%
plt.imshow(img_bgr)

# %% [markdown]
# 4. Save the image as a PNG file using OpenCV imwrite().

# %%
cv2.imwrite('Apollo-11-launch.jpg',img_bgr)
# Out:
# True

# %% [markdown]
# 5. Read the saved image above as a color image using cv2.cvtColor().

# %%
img = cv2.imread('bf.png')
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 6. Display the Colour image using matplotlib imshow() & Print the image width, height & channel

# %%
plt.imshow(img)
h, w, c = img.shape
print("Width:", w, "Height:", h, "Channels:", c)
# Out:
# Width: 501 Height: 499 Channels: 3

# %% [markdown]
# 7. Crop the image to extract any specific (Eagle alone)  object from the image.

# %%
cropped_img =img_bgr[30:425,200:550]
plt.imshow(cropped_img[:,:,::-1])
plt.title('Cropped image')
plt.axis('off')
plt.show()

# %% [markdown]
# 8. Resize the image up by a factor of 2x.

# %%
resized_img = cv2.resize(cropped_img, None, fx=50, fy=50, interpolation=cv2.INTER_LINEAR)

# %% [markdown]
# 9. Flip the cropped/resized image horizontally. (Eagle Image)

# %%
flipped_img = cv2.flip(cropped_img, 1)
flip_color = cv2.cvtColor(flipped_img, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=[20,20])
plt.subplot(221)
plt.imshow(cropped_img[:,:,::-1])
plt.title("normal cropped image")
plt.subplot(222)
plt.imshow(flip_color)
plt.title("flipped cropped image")
# Out:
# Text(0.5, 1.0, 'flipped cropped image')

# %% [markdown]
# 10. Read in the image ('Apollo-11-launch.jpg').

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
apollo = cv2.imread("Apollo-11-launch.jpg")
apollo = cv2.cvtColor(apollo, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 11. Add the following text to the dark area at the bottom of the image (centered on the image):

# %%
apollo = cv2.imread("Apollo-11-launch.jpg")
apollo = cv2.cvtColor(apollo, cv2.COLOR_BGR2RGB)

# Add text
text = 'Apollo 11 Saturn V Launch, July 16, 1969'
cv2.putText(apollo, text, (50, apollo.shape[0]-30),
            cv2.FONT_HERSHEY_PLAIN, 1.5, (255,255,255), 2)
# Out:
# array([[[213, 213, 213],
#         [213, 213, 213],
#         [210, 210, 210],
#         ...,
#         [241, 241, 241],
#         [240, 240, 240],
#         [241, 241, 241]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [239, 239, 239],
#         [240, 240, 240]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        ...,
#
#        [[ 47,  47,  47],
#         [ 46,  46,  46],
#         [ 42,  42,  42],
#         ...,
#         [ 17,  17,  17],
#         [ 11,  11,  11],
#         [  5,   5,   5]],
#
#        [[ 44,  44,  44],
#         [ 47,  47,  47],
#         [ 47,  47,  47],
#         ...,
#         [ 17,  17,  17],
#         [ 10,  10,  10],
#         [  4,   4,   4]],
#
#        [[ 43,  43,  43],
#         [ 49,  49,  49],
#         [ 52,  52,  52],
# ...

# %% [markdown]
# 12. Draw a magenta rectangle that encompasses the launch tower and the rocket.

# %%
cv2.rectangle(apollo, (500, 100), (750, 920), (255, 0, 255), 3)
# Out:
# array([[[213, 213, 213],
#         [213, 213, 213],
#         [210, 210, 210],
#         ...,
#         [241, 241, 241],
#         [240, 240, 240],
#         [241, 241, 241]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [239, 239, 239],
#         [240, 240, 240]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        ...,
#
#        [[ 47,  47,  47],
#         [ 46,  46,  46],
#         [ 42,  42,  42],
#         ...,
#         [ 17,  17,  17],
#         [ 11,  11,  11],
#         [  5,   5,   5]],
#
#        [[ 44,  44,  44],
#         [ 47,  47,  47],
#         [ 47,  47,  47],
#         ...,
#         [ 17,  17,  17],
#         [ 10,  10,  10],
#         [  4,   4,   4]],
#
#        [[ 43,  43,  43],
#         [ 49,  49,  49],
#         [ 52,  52,  52],
# ...

# %% [markdown]
# 13. Display the final annotated image.

# %%
plt.imshow(apollo)
plt.title("Annotated Image")
plt.axis('off')
plt.show()

# %% [markdown]
# 14. Read the image ('boy.jpg').

# %%
img = cv2.imread("boy.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 15. Adjust the brightness of the image.

# %%
matrix = np.ones(img.shape, dtype='float64') * 50

# %% [markdown]
# 16. Create brighter and darker images.

# %%
img_brighter = cv2.add(img, matrix.astype(np.uint8))
img_darker = cv2.subtract(img, matrix.astype(np.uint8))

# %% [markdown]
# 17. Display the images (Original Image, Darker Image, Brighter Image).

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,3,1)
plt.imshow(img)
plt.title("Original")

plt.subplot(1,3,2)
plt.imshow(img_darker)
plt.title("Darker")

plt.subplot(1,3,3)
plt.imshow(img_brighter)
plt.title("Brighter")

plt.show()

# %% [markdown]
# 18. Modify the image contrast.

# %%
img_higher1 = cv2.convertScaleAbs(img, alpha=1.1, beta=0)
img_higher2 = cv2.convertScaleAbs(img, alpha=1.2, beta=0)

# %% [markdown]
# 19. Display the images (Original, Lower Contrast, Higher Contrast).

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,3,1)
plt.imshow(img)
plt.title("Original")

plt.subplot(1,3,2)
plt.imshow(img_higher1)
plt.title("Contrast 1.1")

plt.subplot(1,3,3)
plt.imshow(img_higher2)
plt.title("Contrast 1.2")

plt.show()

# %% [markdown]
# 20. Split the image (boy.jpg) into the B,G,R components & Display the channels.

# %%
img_bgr2 = cv2.imread("boy.jpg")
b, g, r = cv2.split(img_bgr2)

plt.imshow(b, cmap='gray')
plt.title("Blue Channel")
plt.show()

plt.imshow(g, cmap='gray')
plt.title("Green Channel")
plt.show()

plt.imshow(r, cmap='gray')
plt.title("Red Channel")
plt.show()

# %% [markdown]
# 21. _merged the R, G, B , display along with orginal image

# %%
merged = cv2.merge((b, g, r))
merged = cv2.cvtColor(merged, cv2.COLOR_BGR2RGB)

plt.imshow(merged)
plt.title("Merged Image")
plt.axis('off')
plt.show()

# %% [markdown]
# 22. Split the image into the H, S, V components &  Display the channels.

# %%
hsv = cv2.cvtColor(img_bgr2, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv)

plt.imshow(h, cmap='gray')
plt.title("Hue")
plt.show()

plt.imshow(s, cmap='gray')
plt.title("Saturation")
plt.show()

plt.imshow(v, cmap='gray')
plt.title("Value")
plt.show()

# %% [markdown]
# 23. _merged the H, S, V, display along with orginal image

# %%
merged_hsv = cv2.merge((h, s, v))
final_img = cv2.cvtColor(merged_hsv, cv2.COLOR_HSV2RGB)

plt.imshow(final_img)
plt.title("HSV Merged Image")
plt.axis('off')
plt.show()
